# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
traindf=pd.read_csv('./train.csv',sep=',')
traindf
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# 5              6         0       3
# 6              7         0       1
# 7              8         0       3
# 8              9         1       3
# 9             10         1       2
# 10            11         1       3
# 11            12         1       1
# 12            13         0       3
# 13            14         0       3
# 14            15         0       3
# 15            16         1       2
# 16            17         0       3
# 17            18         1       2
# 18            19         0       3
# 19            20         1       3
# 20            21         0       2
# 21            22         1       2
# 22            23         1       3
# 23            24         1       1
# 24            25         0       3
# ...

# %%
traindf.dtypes
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %%
traindf.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
traindf[['Sex','Survived']].groupby('Sex',as_index=False).mean().sort_values(by="Survived",ascending=False)
# Out:
#       Sex  Survived
# 0  female  0.742038
# 1    male  0.188908

# %%
traindf[['Pclass','Survived']].groupby('Pclass',as_index=False).mean().sort_values(by='Survived',ascending=False)
# Out:
#    Pclass  Survived
# 0       1  0.629630
# 1       2  0.472826
# 2       3  0.242363

# %%
traindf[['Parch','Survived']].groupby('Parch',as_index=False).mean()
# Out:
#    Parch  Survived
# 0      0  0.343658
# 1      1  0.550847
# 2      2  0.500000
# 3      3  0.600000
# 4      4  0.000000
# 5      5  0.200000
# 6      6  0.000000

# %%
display(traindf[['Age','Survived']].groupby('Age',as_index=False).mean())
# Out:
#       Age  Survived
# 0    0.42  1.000000
# 1    0.67  1.000000
# 2    0.75  1.000000
# 3    0.83  1.000000
# 4    0.92  1.000000
# 5    1.00  0.714286
# 6    2.00  0.300000
# 7    3.00  0.833333
# 8    4.00  0.700000
# 9    5.00  1.000000
# 10   6.00  0.666667
# 11   7.00  0.333333
# 12   8.00  0.500000
# 13   9.00  0.250000
# 14  10.00  0.000000
# 15  11.00  0.250000
# 16  12.00  1.000000
# 17  13.00  1.000000
# 18  14.00  0.500000
# 19  14.50  0.000000
# 20  15.00  0.800000
# 21  16.00  0.352941
# 22  17.00  0.461538
# 23  18.00  0.346154
# 24  19.00  0.360000
# 25  20.00  0.200000
# 26  20.50  0.000000
# 27  21.00  0.208333
# 28  22.00  0.407407
# 29  23.00  0.333333
# ..    ...       ...
# 58  44.00  0.333333
# 59  45.00  0.416667
# 60  45.50  0.000000
# 61  46.00  0.000000
# 62  47.00  0.111111
# 63  48.00  0.666667
# 64  49.00  0.666667
# 65  50.00  0.500000
# 66  51.00  0.285714
# 67  52.00  0.500000
# 68  53.00  1.000000
# 69  54.00  0.375000
# 70  55.00  0.500000
# ...

# %%
plt.scatter(traindf[['Pclass','Survived']].groupby('Pclass',as_index=False).mean()['Pclass'].values,traindf[['Pclass','Survived']].groupby('Pclass',as_index=False).mean()['Survived'].values)
